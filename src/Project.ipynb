# %% [markdown]
# # Path Finding Maze Generator Project

# %%
using Revise, BenchmarkTools

# %%
includet("../Project/MazeGenerator.jl")
using .MazeGenerator
include("../Project/Test-MazeGenerator.jl")
# Out:
# Test Summary:    | Pass  Total
# Node Constructor |    2      2
# Test Summary:    | Pass  Total
# Grid Constructor |    2      2
# Test Summary: | Pass  Total
# Node Tests    |    3      3
# Test Summary: | Pass  Total
# Create Maze   |    5      5
# Test.DefaultTestSet("Create Maze", Any[], 5, false)

# %%
#mazeTime = @belapsed(MazeGenerator.createMaze(14,33))

# %%
maze = MazeGenerator.createMaze(33,33)
MazeGenerator.plotMaze(maze)

# %%
#solveTime = @belapsed(MazeGenerator.solveMaze(maze))

# %%
maze = MazeGenerator.solveMaze(maze)
MazeGenerator.plotMaze(maze)

# %%
MazeGenerator.plotSolution(maze)
# Out:
# ┌ Info: Saved animation to
# │   fn = C:\Users\xarro\desktop\school\FALL 2020\Comp Sci\sci-comp-notebooks\Project\out.gif
# └ @ Plots C:\Users\xarro\.julia\packages\Plots\hyS17\src\animation.jl:104
# Plots.AnimatedGif("C:\\Users\\xarro\\desktop\\school\\FALL 2020\\Comp Sci\\sci-comp-notebooks\\Project\\out.gif")
